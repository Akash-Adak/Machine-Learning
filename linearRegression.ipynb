# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-Adak/Machine-Learning/blob/main/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import  LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/ml practice/homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x=df[['area']]
y=df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [596355.14018692]

# %%
model.coef_
# Out:
# array([128.27102804])

# %%
model.intercept_
# Out:
# np.float64(211542.05607476638)

# %%
3300* 128.27102804 + 211542.05607476638
# Out:
# 634836.4486067664

# %%
x_line = np.linspace(df['area'].min(), df['area'].max(), 100).reshape(-1, 1)
y_line = model.predict(x_line)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x, y, color='blue', label="Actual Data")
plt.plot(x_line, y_line, color='red', label=f"Regression Line\n{equation}")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.grid(True)
